# %%
import yfinance as yf
import pandas as pd
appleStock = yf.Ticker("AAPL")
appleStock = appleStock.history(start='2018-01-01', end='2019-12-9')
appleOpenPrices = appleStock['Open'].tolist()
appleDates = appleStock.index.tolist()
microsoftStock = yf.Ticker("MSFT")
microsoftStock = microsoftStock.history(start='2018-01-01', end='2019-12-9')
microsoftOpenPrices = microsoftStock['Open'].tolist()
microsoftDates = microsoftStock.index.tolist()
teslaStock = yf.Ticker("TSLA")
teslaStock = teslaStock.history(start='2018-01-01', end='2019-12-9')
teslaOpenPrices = teslaStock['Open'].tolist()
teslaDates = teslaStock.index.tolist()

# %%
frame={
    'date':appleDates,
    'apple':appleOpenPrices,
    'microsoft':microsoftOpenPrices,
    'tesla':teslaOpenPrices
}
df=pd.DataFrame(frame,index=appleDates)
df
# Out:
#                  date      apple   microsoft      tesla
# 2018-01-02 2018-01-02  40.604423   82.556168  62.400002
# 2018-01-03 2018-01-03  41.169962   82.489076  64.199997
# 2018-01-04 2018-01-04  41.172341   82.997094  62.574001
# 2018-01-05 2018-01-05  41.387107   84.022693  63.324001
# 2018-01-08 2018-01-08  41.604263   84.540284  63.200001
# ...               ...        ...         ...        ...
# 2019-12-02 2019-12-02  65.707420  150.218634  65.879997
# 2019-12-03 2019-12-03  63.504647  145.943929  66.524002
# 2019-12-04 2019-12-04  64.183180  148.566128  67.550003
# 2019-12-05 2019-12-05  64.851886  148.477105  66.566002
# 2019-12-06 2019-12-06  65.759051  149.407243  67.000000
#
# [487 rows x 4 columns]

# %%
import plotly.express as px
fig = px.line(df, x='date', y=['apple','microsoft','tesla'])
fig.show()
# Out:
# <div>                            <div id="1a57d19c-75fb-4db5-8720-4ae86f9be3fd" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1a57d19c-75fb-4db5-8720-4ae86f9be3fd")) {                    Plotly.newPlot(                        "1a57d19c-75fb-4db5-8720-4ae86f9be3fd",                        [{"hovertemplate": "variable=apple<br>date=%{x}<br>value=%{y}<extra></extra>", "legendgroup": "apple", "line": {"color": "#636efa", "dash": "solid"}, "mode": "lines", "name": "apple", "showlegend": true, "type": "scattergl", "x": ["2018-01-02T00:00:00", "2018-01-03T00:00:00", "2018-01-04T00:00:00", "2018-01-05T00:00:00", "2018-01-08T00:00:00", "2018-01-09T00:00:00", "2018-01-10T00:00:00", "2018-01-11T00:00:00", "2018-01-12T00:00:00", "2018-01-16T00:00:00", "2018-0
# ...

# %%
data_canada = px.data.gapminder().query("country == 'Canada'")
data_canada
# Out:
#     country continent  year  lifeExp       pop    gdpPercap iso_alpha  iso_num
# 240  Canada  Americas  1952   68.750  14785584  11367.16112       CAN      124
# 241  Canada  Americas  1957   69.960  17010154  12489.95006       CAN      124
# 242  Canada  Americas  1962   71.300  18985849  13462.48555       CAN      124
# 243  Canada  Americas  1967   72.130  20819767  16076.58803       CAN      124
# 244  Canada  Americas  1972   72.880  22284500  18970.57086       CAN      124
# 245  Canada  Americas  1977   74.210  23796400  22090.88306       CAN      124
# 246  Canada  Americas  1982   75.760  25201900  22898.79214       CAN      124
# 247  Canada  Americas  1987   76.860  26549700  26626.51503       CAN      124
# 248  Canada  Americas  1992   77.950  28523502  26342.88426       CAN      124
# 249  Canada  Americas  1997   78.610  30305843  28954.92589       CAN      124
# 250  Canada  Americas  2002   79.770  31902268  33328.96507       CAN      124
# ...
